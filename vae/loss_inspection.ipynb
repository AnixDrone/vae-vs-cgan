# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
loss_df = pd.read_csv("models_save/losses.csv")

# %%
plt.plot(loss_df["train_loss"],label="train")
plt.plot(loss_df["test_loss"],label="test")
plt.show()
